# %%
import requests
from urllib.request import Request, urlopen
import re
from bs4 import BeautifulSoup

class Webscrapper:
    def __init__(self, mode):
        self.url = ""
        self.mode = mode
        self.soup = ""
    def getMode(self):
        return self.mode 

    def set_Mode(self, mode):
        self.mode = mode

    def getURL(self):
        return self.url 

    def set_URL(self, values):
        #structure for values tuple (0:template for url, 1:tuple of values)
        template = values[0]
        if self.getMode() == "url":
            self.url = template.format(values[1][0], values[1][1])  
            self.url = self.url.replace(" ", "%20")
        if self.getMode() =="job":
            self.url = template.format(values[1])
            print(self.url)

    def createSoup(self):
        req = Request(self.getURL(), headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req).read()
        self.soup = BeautifulSoup(webpage, 'html.parser')

    def webScrape(self, jobPosts=[], searchQuery=["",""]):
        #URL mode will return a list of  tuples of (jobTitle, jobCompany, JobID)
        cleaner =  re.compile('<.*?>')
        if self.getMode() =="url":
            position = searchQuery[0]
            location = searchQuery[1] 
            jobIDs = []
            self.set_URL(('https://uk.indeed.com/jobs?q={}&l={}',(position, location)))
            self.createSoup()
            cards = self.soup.find_all('div', 'job_seen_beacon')
            mosaic = self.soup.find('div', {"id" : "mosaic-provider-jobcards"})
            jobIDs = self.jobID(mosaic)
            index = 0
            while index < 3:
                c = cards[index]
                tempTitle = self.jobTitle(c)
                title = self.cleanhtml(tempTitle, cleaner)
                tempCompany = self.companyName(c)
                company = self.cleanhtml(tempCompany, cleaner)
                jobPosts.append((title,company,jobIDs[index]))
                index += 1
            return jobPosts
        if self.getMode() == "job":
            jobsList = []
            for j in jobPosts:
                self.set_URL(('https://www.indeed.com/viewjob?viewtype=embedded&jk={}',j[2]))
                self.createSoup()
                jobDesc= self.jobDescription(self.soup)
                clean = self.cleanhtml(jobDesc, cleaner)
                jobsList.append((j[0],j[1],clean))
            return jobsList

    def jobID(self, mosaic):
        mosaicsAnchors = [] 
        ids = []
        pattern = 'result job_\w+'
        tempMosaicsAnchors = self.soup.findAll('a')
        for a in tempMosaicsAnchors:
            if("tapItem fs-unmask result" in str(a)):
                mosaicsAnchors.append(a)
        for m in mosaicsAnchors:
            result = re.findall(pattern, str(m))
            job = result[0].split(' ')[1]
            jobID = job.split('_')[1]
            ids.append(jobID)
        return ids

    def jobTitle(self, card):
        h2 = card.h2
        spans = h2.findAll('span')
        for s in spans:
            if('title' in str(s)):
                jobTitle = s
                return jobTitle
        return None

    #Get Job Company
    def companyName(self, card):  
        spans = card.findAll('span')
        for s in spans:
            if('companyName' in str(s)):
                companyName = s
                return companyName
        return None

    def jobDescription(self, jobSoup):
        return jobSoup.find('div', 'jobsearch-jobDescriptionText')


    def cleanhtml(self,raw_html,cleaned):
            cleantext = re.sub(cleaned, ' ' , str(raw_html))
            return cleantext

# %%
class Job:
    def __init__(self, values):
        self.title = values[0]
        self.company = values[1]
        self.description = values[2]

    def getTitle(self):
        return self.title

    def getCompany(self):
        return self.company

    def getDescription(self):
        return self.description

# %%
import pandas as pd
ws = Webscrapper("url")
job = input() 
JobPosts= ws.webScrape(searchQuery=(str(job),''))
ws.set_Mode('job')
JobPostings = ws.webScrape(jobPosts=JobPosts)
#jobs =[Job(list(j)) for j in JobPostings]
jobList = [list(j) for j in JobPostings]
df = pd.DataFrame(jobList, columns = ['Title', 'Company', 'Job Description'])
display(df)
"""
df.to_csv('JobPostings.csv',mode='a', index=False, header=False)
"""
JobPosts.clear()
jobList.clear()
# Out:
#   File "C:\Users\Edgar\AppData\Local\Temp/ipykernel_4240/3513516458.py", line 13
#     """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
class Skills:
    def __init__(self, values):
        self.skills = values[0]
        self.softSkills = values[1]

    def getTitle(self):
        return self.skills

    def getCompany(self):
        return self.softSkills

# %%
s = Skills(([0],[0]))

# %%
s.getCompany()
# Out:
# [0]

# %%
extract = pd.read_csv('JobPostings.csv', encoding='ISO-8859-1')

# %%
extract
# Out:
#                                                 Title  \
# 0                                Assistant Accountant
# 1                        Financial Accountant (Food)
# 2                 Financial and Reporting Accountant
# 3                         Business Analyst (2 posts)
# 4                Business Analyst Agile - Technology
# 5                        Business Management Analyst
# 6    Business Support Officer for Gardens and Land...
# 7                                    Finance Officer
# 8                          Volunteer Support Officer
# 9    Civil Engineer (Site Engineer in Sydney Austr...
# 10   Civil Engineer â Graduate Programme Septemb...
# 11                                    Civil Engineer
# 12                     2022 Entertainments Performer
# 13    Production Apprenticeship Fast Track - England
# 14            Freelance 2D Animators // Illustrators
# 15   Registered Nurse - Visa sponsorship available...
# 16       Internationally Educated Nurse awaiting PIN
# 17                Registered Degree Nurse Apprentice
# 18                                 Nursing Home Chef
# 19                              Restaurant Prep Chef
# 20                     Chef Manager Monday to Friday
# 21                             Management Consultant
# 22       2022 Graduate Analyst and Consultant Intake
# 23                  IT Service Management Consultant
# 24   Solicitor Apprenticeship (BCC and Womble Bond...
# 25                                         Solicitor
# 26   BSO_Solicitor Consultant Mental Capacity Law ...
# 27   SIA Door Supervisor &amp; Stewards - Events &...
# 28             Security Guard Days - Immediate Start
# 29                                  Security Officer
# 30               Personal Trainer/Fitness Instructor
# 31             Personal Training Recruitment Manager
# 32                Personal Trainer job in Manchester
# 33   Home based Telephone Market Research Intervie...
# 34   English Speaking Market Research Interviewer ...
# 35   ARMENIAN-speaking Market Research Telephone I...
# 36   Crew for servicing FILM TV &amp; EVENT WORK (...
# 37                                 Production Intern
# 38                                           Runners
# 39                   Bookseller - Manchester Airport
# 40                              Book Sales Assistant
# 41      Weekend Bookseller 15hrs - Selfridges London
# 42                                  SENIOR SCIENTIST
# 43        Laboratory Scientist Degree Apprenticeship
# 44                            Cytogenetics scientist
# 45   Retail Sales Assistant - French Connection - ...
# 46   Sales Associate Wine Shop 20 &amp; 25 hours (...
# 47         Sales Associate - Selfridges (Manchester)
# 48                  Social Worker - Children in Care
# 49                                  Home Care Worker
# 50   Social Worker - Â£45 per hour plus Accommodat...
# 51                     Teaching and Learning Officer
# 52   Teaching, Learning And Student Experience Coo...
# 53            Teacher of Science - Granville Academy
# 54                           Cabin Crew - Manchester
# 55                       Cabin Crew - Leeds Bradford
# 56                                 Cabin Crew Member
#
#                                               Company  \
# 0                        Egress Software Technologies
# 1                                              Coop
# 2                                               AQA
# 3                      The University of Manchester
# 4                                      clientserver
# 5                                     Deutsche Bank
# 6                                  English Heritage
# 7                                The Wildlife Trusts
# 8                                    EPILEPSY ACTION
# 9                              Vaughan Civil Pty Ltd
# 10                                        RPS Group
# 11                        Mackenzie Construction Ltd
# 12                              Alton Towers Resort
# 13                                              BBC
# 14                                              Bloc
# 15                                    Grove Care Ltd
# 16    East Kent Hospitals University NHS Foundatio...
# 17      University Hospitals of Morecambe Bay NHS...
# 18             CARE SOLUTIONS RECRUITMENT AGENCY LTD
# 19                                       Tampopo Ltd
# 20                                       Wilson Vale
# 21                         The Berkeley Partnership
# 22                                   Quick Release_
# 23                                     iCore Limited
# 24                             Bristol City Council
# 25                          Derbyshire Constabulary
# 26                      Health and Social Care Trust
# 27                         Practical Event Solutions
# 28               NationWide Management Services Ltd
# 29                                   Five Star Group
# 30                                       TBT Fitness
# 31                                  Love Recruitment
# 32                                  Love Recruitment
# 33                             B2B International Ltd
# 34                   Global Data Collection Company
# 35                              Ronin International
# 36                                  Buddha Group Ltd
# 37                            Universal Music Group
# 38                       Molinare TV &amp; Film LTD.
# 39                                          WHSmith
# 40                                               MPR
# 41                                          WHSmith
# 42                                             Evove
# 43                                         Syngenta
# 44                   Hematogenix Laboratory Services
# 45                                French Connection
# 46                                       Selfridges
# 47                           Luxottica Retail UK Ltd
# 48                       Warrington Borough Council
# 49                     Star Domiciliary Care Limited
# 50                               NonStop Consulting
# 51                     The University of Manchester
# 52                     The University of Manchester
# 53                              The de Ferrers Trust
# 54                        Jet2.com and Jet2holidays
# 55                        Jet2.com and Jet2holidays
# 56                                  Loganair Limited
#
#                                       Job Description
# 0   Assistant Accountant Egress is looking for an ...
# 1       Financial Accountant (Food)  \nÂ£40,000 - ...
# 2       At AQA, weâre committed to advancing edu...
# 3         Business Analyst, Grade 7, IT Services\n...
# 4    Business Analyst (Agile) *Hybrid WfH*. Are yo...
# 5          Job Title:  Business Management Analyst...
# 6          Are you looking for a part-time role, w...
# 7         Part time: 0.4FTE (14 hours a week)    \...
# 8      Volunteer Support Officer â Talk and Supp...
# 9      WHO ARE WE:  Vaughan Civil Pty Ltd is a pri...
# 10       We are looking for Graduates to join our ...
# 11    Working within our Structural Repairs team, ...
# 12        2022 Entertainments Performer    \nAlton...
# 13    Job Introduction\n  \nWhat youâll get  \n ...
# 14    Are you an extremely talented 2D animator an...
# 15    Grove Care are a well-established provider o...
# 16    When completing your application:  Clearly s...
# 17   This vacancy will close early if high volumes...
# 18    Care Solutions Recruitment Agency Ltd is cur...
# 19     WHY WORK FOR US:     Great Tronc system - e...
# 20     What makes our hearts beat? Inspirational f...
# 21    When we ask someone to join The Berkeley Par...
# 22      Quick Release is a next-generation boutiqu...
# 23     Due to significant growth and ever-increasi...
# 24       University isn't for everyone but that do...
# 25     Weâll challenge you to work outside your ...
# 26      Branch:  Belfast (BSO) \n  \nLocation:  BS...
# 27    Practical Event Solutions are recruiting SIA...
# 28     Security Guard    Manchester    Security Gu...
# 29    Five Star Group is expanding and have severa...
# 30    Full Time Coaching Opportunity Available Lev...
# 31    Internal Recruitment Manager  Home based wit...
# 32     Personal Trainer Opportunity - Self Employe...
# 33    B2B International is a leading global busine...
# 34      This is a remote position.  \n English Spe...
# 35    RONIN International is a Market Research com...
# 36    We are a very fast growing hire company serv...
# 37      Job title:  Production Intern \n Responsib...
# 38     We are always looking for enthusiastic and ...
# 39          About us  \nVoted Book Retailer of the...
# 40    Mpeople Recruitment are excited to be recrui...
# 41          What youâll do? \nYouâll make our ...
# 42     SENIOR SCIENTIST,   DARESBURY SCI-TECH CAMP...
# 43       Laboratory Scientist Degree Apprenticeshi...
# 44     Company Description:    Hematogenix is a sp...
# 45    French Connection is looking for two dynamic...
# 46    Job Introduction\n \nDo you have a keen inte...
# 47     Sales Associate    Sunglass Hut  is a world...
# 48        We have a strong vision for social work ...
# 49    Personal care includes washing, dressing, ba...
# 50   QSW- Safeguarding Team - Â£45 per hour plus f...
# 51       The University seeks to appoint a Teachin...
# 52     This is an exciting opportunity to join our...
# 53    Salary:  MPS/UPS (Â£25,714 - Â£41,604)  Hour...
# 54         Permanent Percentage\n    Rostered\n   ...
# 55         Permanent Percentage\n    Rostered\n   ...
# 56     Cabin Crew    Â£16,868 - Â£23,844    Plus c...
